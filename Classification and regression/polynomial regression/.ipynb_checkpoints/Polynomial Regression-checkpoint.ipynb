# %% [markdown]
# <font color='blue'><h1>Assignment 3: Lab 2 "Ishwor Luitel 1928727"</h1></font>

# %%
# Polynomial Regression

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:2].values
y = dataset.iloc[:, 2].values

# %% [raw]
# # Explanation of the libraries that are imported for various purposes.
#
#     Numpy: Numpy is an universally useful cluster preparing bundle.It gives an elite multidimensional array objects, and tools for working with these arrays. It is the major bundle for logical registering with Python.Other than its undeniable logical uses, Numpy can likewise be utilized as a proficient multi-dimensional holder of nonexclusive information.
#
#     Pandas: Pandas is an opensource library that permits one to perform information control in Python. Pandas library is based over Numpy, which means Pandas needs Numpy to work. Pandas give a simple method to make, control and wrangle the information.
#
#     Matplotlib: Matplotlib is a Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms.
#
#     # Importing the dataset
# Dataset.iloc[] method is used when a data set's index label is something else than 0, 1, 2, 3 .... n numerical or when the index label is unknown to the user.
#
# # Encoding categorical data
# One hot encryption is to transform each group into a new column, assigning the column to a value of 1 or 0 (True / False). This does not benefit from the excessive weighting of a number but the downside is that more columns are applied to the data set.
# The use of a technique known as mark encoding is another way to represent categorical values. Increasing value is simply translated into a number by the Label Encoding column.

# %%
# Fitting Linear Regression to the dataset
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)

# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
poly_reg.fit(X_poly, y)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [raw]
# # Fitting Linear Regression to the dataset
# LinearRegression fits a linear model with coefficients w = (w1, …, wp) to minimize the residual sum of squares between the observed targets in the dataset, and the targets predicted by the linear approximation.
# Regression model a prediction value based on independent variables. regression modeling It is used mainly to determine the relation between variables and predictions. The form of relation between dependent and independent variables, considered and number of independent variables used, varies according to different models of regression.
#
# # Fitting Polynomial Regression to the dataset
# Polynomial Regression is a form of linear regression in which the relationship between the independent variable x and dependent variable y is modeled as an nth degree polynomial. Polynomial regression fits a nonlinear relationship between the value of x and the corresponding conditional mean of y, denoted E(y |x).
# PolynomialFeatures generates a new matrix with all polynomial combinations of features with given degree.

# %%
# Visualising the Linear Regression results
plt.scatter(X, y, color = 'yellow')
plt.plot(X, lin_reg.predict(X), color = 'blue')
plt.title('Truth or Bluff (Linear Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [raw]
# # Understanding the Linear Regression result
# Above data has a tendency of growing non linearly,so we are required to use a Polynomial Regression for this case.

# %%
# Visualising the Polynomial Regression results
plt.scatter(X, y, color = 'yellow')
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %%
# Visualising the Polynomial Regression results (for higher resolution and smoother curve)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'yellow')
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [raw]
# # Visualising the Polynomial Regression results (for higher resolution and smoother curve)
# With a 4-degree polynomial regression, we obtained a model that has closely predicted the Salary values. If we used a simple linear regression instead, we could not obtain this level of accuracy.

# %%
# Predicting a new result with Linear Regression
test_X1 = np.array(6.5).reshape(-1, 1)
lin_reg.predict(test_X1)
# Out:
# array([330378.78787879])

# %% [raw]
# # Predicting a new result with Linear Regression
# The fundamental data type of NumPy is the array type called numpy.ndarray.The inputs (regressors, 𝑥) and output (predictor, 𝑦) should be arrays (the instances of the class numpy.ndarray) or similar objects. This is the simplest way of providing data for regression.we should call .reshape() on x because this array is required to be two-dimensional, or to be more precise, to have one column and as many rows as necessary. That’s exactly what the argument (-1, 1) of .reshape() specifies.

# %%
# Predicting a new result with Polynomial Regression
test_X2 = np.array(6.5).reshape(-1, 1)
lin_reg_2.predict(poly_reg.fit_transform(test_X2))
# Out:
# array([158862.45265153])

# %% [raw]
# # Predicting a new result with Polynomial Regression
# The polynomial features of degree 2 helped to fit the data much better rather than simple linear features.
